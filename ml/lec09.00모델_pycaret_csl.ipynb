# %% [markdown]
# <font size=6><b>Lec09. pycaret (모델선택)

# %% [markdown]
# * ref : https://pycaret.readthedocs.io/en/latest/api/regression.html?highlight=regression#module-pycaret.regression
# * ref : https://github.com/pycaret/pycaret/blob/master/examples/Pima%20Model.ipynb
# * rer : https://pycaret.gitbook.io/docs/learn-pycaret/examples

# %%
# ! pip install pycaret
# Out:
# ...
#      ------------------------------------- 320.2/320.2 kB 20.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 88.2/88.2 kB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached scipy-1.5.4-cp38-cp38-win_amd64.whl (31.4 MB)
# ...
#   Using cached gensim-3.8.3-cp38-cp38-win_amd64.whl (24.2 MB)
# ...
#   Using cached nltk-3.7-py3-none-any.whl (1.5 MB)
# ...
#   Using cached imbalanced_learn-0.7.0-py3-none-any.whl (167 kB)
# ...
#      ---------------------------------------- 17.0/17.0 MB 7.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.3/1.3 MB 6.6 MB/s eta 0:00:00
# ...
#      -------------------------------------- 274.2/274.2 kB 5.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.3/2.3 MB 6.1 MB/s eta 0:00:00
# ...
#   Using cached Boruta-0.3-py3-none-any.whl (56 kB)
# ...
#      -------------------------------------- 262.6/262.6 kB 5.4 MB/s eta 0:00:00
# ...
